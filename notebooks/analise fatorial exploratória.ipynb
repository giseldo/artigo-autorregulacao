# %%
import pandas as pd
import numpy as np
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import FactorAnalysis
from factor_analyzer import FactorAnalyzer, calculate_bartlett_sphericity, calculate_kmo
import matplotlib.pyplot as plt
from factor_analyzer import FactorAnalyzer, calculate_bartlett_sphericity, calculate_kmo
import matplotlib.pyplot as plt
from semopy import Model, calc_stats
from sklearn.preprocessing import StandardScaler
from factor_analyzer import FactorAnalyzer, calculate_bartlett_sphericity, calculate_kmo
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from factor_analyzer import FactorAnalyzer, calculate_bartlett_sphericity, calculate_kmo
from factor_analyzer import FactorAnalyzer, calculate_bartlett_sphericity, calculate_kmo
import matplotlib.pyplot as plt
from factor_analyzer import FactorAnalyzer, calculate_bartlett_sphericity, calculate_kmo
import matplotlib.pyplot as plt
from semopy import Model, calc_stats

# %%
df = pd.read_csv("..\data\questionario_assertivas.csv", delimiter=";")

df.head()
# Out:
#    P1  P10  P2  P13  P4  P5  P7  P15  P17  P21  ...  P37  P38  P39  P40  P35  \
# 0   6    3   4    5   4   6   5    5    5    6  ...    6    5    5    4    4
# 1   3    6   4    4   5   4   3    5    5    7  ...    3    2    4    6    5
# 2   7    7   1    6   7   4   5    7    7    7  ...    7    5    7    7    7
# 3   7    4   5    6   6   6   7    6    6    6  ...    4    6    6    6    6
# 4   7    5   7    7   7   7   7    7    7    7  ...    7    7    6    7    5
#
#    P14  P27  P29  P33  P43
# 0    5    6    5    5    2
# 1    6    1    7    5    4
# 2    7    4    7    7    7
# 3    7    6    6    5    5
# 4    7    7    7    7    7
#
# [5 rows x 44 columns]

# %%
fa = FactorAnalyzer(n_factors=5, rotation=None)

fa.fit(df)

eigenvalues, _ = fa.get_eigenvalues()

plt.scatter(range(1, df.shape[1]+1), eigenvalues)
plt.plot(range(1, df.shape[1]+1), eigenvalues)
plt.title("Grafico Scree")
plt.xlabel('Número de Fatores')
plt.ylabel('Autovalores')
plt.grid()
plt.show()

loadings = fa.loadings_
factors = pd.DataFrame(loadings, index=df.columns, columns=['Factor1', 'Factor2', 'Factor3', 'Factor4', 'Factor5'])
factors
# Out:
#       Factor1   Factor2   Factor3   Factor4   Factor5
# P1   0.399337 -0.216846  0.029944  0.084498 -0.220560
# P10  0.503986 -0.085589  0.212227  0.032318 -0.136309
# P2   0.347514 -0.211901  0.422015  0.127628 -0.153170
# P13  0.643939 -0.336809  0.269749  0.073078  0.148391
# P4   0.604346 -0.082599 -0.295330 -0.140396 -0.182455
# P5   0.489902 -0.291929 -0.004744 -0.017121  0.068940
# P7   0.628623 -0.059604  0.066388 -0.226104 -0.180466
# P15  0.644715 -0.515504  0.200920  0.064733  0.130764
# P17  0.639347 -0.445236  0.118103  0.020775  0.492849
# P21  0.655962  0.060875  0.068218 -0.165237 -0.355570
# P9   0.565852 -0.088363  0.358168  0.177281 -0.271170
# P16  0.602836 -0.076896  0.573911  0.276534 -0.016873
# P18  0.512722 -0.284846  0.431935  0.241428  0.132488
# P6   0.585188 -0.339709 -0.067673 -0.145469  0.075815
# P8   0.742409 -0.141525  0.007128 -0.124612 -0.273400
# P11  0.709865 -0.328447  0.217660 -0.138706 -0.348512
# P19  0.664174 -0.266429 -0.125094 -0.170744  0.158636
# P3   0.201108  0.279068 -0.007331  0.003116  0.151084
# P12 -0.001624  0.422707  0.490881 -0.016472  0.353949
# P20  0.448478  0.127800  0.397231  0.029417  0.361930
# P22 -0.136760  0.682780  0.344751 -0.030624 -0.035065
# P30  0.543185  0.306912 -0.080302 -0.332129  0.380958
# P24  0.326987  0.389552 -0.108791 -0.000856  0.171920
# P32  0.535188  0.076034  0.091432  0.338348  0.082131
# P34  0.511129  0.541420 -0.151076  0.451286 -0.125365
# P36  0.298440  0.354306 -0.210182  0.238247  0.238351
# P41  0.517346  0.521277 -0.030059  0.442657 -0.046316
# P23  0.595066  0.266031  0.157774 -0.454954  0.193915
# P44  0.531382 -0.059502 -0.519372 -0.097779  0.326682
# P26 -0.101516  0.319783  0.390732 -0.321906 -0.257960
# P31  0.647677  0.280804 -0.018036 -0.508532  0.108755
# P42  0.585406  0.391334  0.050444 -0.408072 -0.132886
# P28  0.556102  0.342071 -0.032641 -0.236551 -0.042051
# P25  0.587318  0.408917  0.033885  0.115186 -0.065379
# P37  0.294165 -0.496635 -0.207878  0.121763 -0.011158
# P38  0.291640 -0.528531 -0.316153  0.155589  0.137679
# P39  0.630058  0.224779 -0.227324 -0.005863  0.116773
# P40  0.603546  0.381408 -0.299664  0.240611 -0.087728
# P35  0.536893  0.431388 -0.171229  0.439932 -0.148781
# P14  0.609402 -0.098642 -0.132848  0.173480  0.211003
# P27  0.390677 -0.294169 -0.285319 -0.098432 -0.385752
# P29  0.572443  0.221349 -0.091743 -0.034091 -0.183245
# P33  0.077279  0.151087 -0.298074 -0.022812 -0.073837
# P43  0.710695 -0.034216 -0.366790  0.019772 -0.061209

# %%
# Extrair apenas as colunas relevantes para a análise fatorial
# Certifique-se de que os dados estejam no formato adequado (por exemplo, numérico)
# Se necessário, você pode precisar codificar variáveis categóricas antes da análise
df = df[df.columns]  

# Inicializar e ajustar o modelo de análise fatorial
fa = FactorAnalyzer(n_factors=3, rotation=None)  # Defina o número de fatores desejados
fa.fit(df)

# Obter os resultados
eigenvalues, _ = fa.get_eigenvalues()

# Plotar o gráfico de scree
plt.scatter(range(1, df.shape[1]+1), eigenvalues)
plt.plot(range(1, df.shape[1]+1), eigenvalues)
plt.title('Gráfico de Scree')
plt.xlabel('Número de Fatores')
plt.ylabel('Autovalores')
plt.grid()
plt.show()

# Extrair os fatores e as cargas fatoriais
loadings = fa.loadings_
factors = pd.DataFrame(loadings, index=df.columns, columns=['Factor1', 'Factor2', 'Factor3'])
factors
# Out:
#       Factor1   Factor2   Factor3
# P1   0.400187 -0.213145  0.037927
# P10  0.505520 -0.083261  0.211379
# P2   0.348670 -0.210625  0.430476
# P13  0.646128 -0.336113  0.275517
# P4   0.604561 -0.079992 -0.296350
# P5   0.492338 -0.291847 -0.001678
# P7   0.627090 -0.053328  0.065943
# P15  0.647933 -0.515142  0.204383
# P17  0.628404 -0.420331  0.106782
# P21  0.650492  0.064996  0.063381
# P9   0.563462 -0.083182  0.354488
# P16  0.601597 -0.073450  0.572363
# P18  0.512296 -0.279528  0.433765
# P6   0.587329 -0.336172 -0.068086
# P8   0.740197 -0.135379  0.008363
# P11  0.704441 -0.315705  0.209429
# P19  0.664592 -0.261033 -0.126550
# P3   0.201391  0.283696 -0.008950
# P12 -0.002583  0.416062  0.467044
# P20  0.444753  0.129183  0.383342
# P22 -0.138800  0.695382  0.348476
# P30  0.532228  0.294897 -0.081748
# P24  0.326980  0.395597 -0.106222
# P32  0.531709  0.075191  0.093441
# P34  0.501551  0.518754 -0.128711
# P36  0.295780  0.348724 -0.197194
# P41  0.509438  0.505158 -0.019045
# P23  0.583403  0.257094  0.134831
# P44  0.528265 -0.053994 -0.509215
# P26 -0.101138  0.311624  0.361710
# P31  0.633860  0.269703 -0.027949
# P42  0.576977  0.381039  0.038588
# P28  0.554666  0.344430 -0.038969
# P25  0.588803  0.417374  0.037519
# P37  0.296580 -0.499658 -0.207532
# P38  0.293490 -0.528196 -0.313885
# P39  0.632009  0.231933 -0.227296
# P40  0.602233  0.382875 -0.294466
# P35  0.527820  0.415339 -0.149846
# P14  0.608657 -0.093956 -0.133372
# P27  0.388020 -0.283508 -0.268449
# P29  0.572964  0.225475 -0.092671
# P33  0.077046  0.151573 -0.303662
# P43  0.714662 -0.030008 -0.375945

# %%
# Estatísticas descritivas
estatisticas_descritivas = df.describe()

# Análise Fatorial Exploratória (AFE)
# Normalizar os dados (opcional, dependendo dos dados)
data_normalized = (data - data.mean()) / data.std()

# Ajustar o modelo de análise fatorial
fa = FactorAnalysis(n_components=5, random_state=0)  # Tentaremos extrair 5 fatores
fa.fit(data_normalized)

# Cargas fatoriais
cargas_fatoriais = pd.DataFrame(fa.components_.T, index=data.columns, columns=[f'Fator {i+1}' for i in range(5)])
cargas_fatoriais
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 6
#       2 estatisticas_descritivas = df.describe()
#       4 # Análise Fatorial Exploratória (AFE)
#       5 # Normalizar os dados (opcional, dependendo dos dados)
# ----> 6 data_normalized = (data - data.mean()) / data.std()
#       8 # Ajustar o modelo de análise fatorial
#       9 fa = FactorAnalysis(n_components=5, random_state=0)  # Tentaremos extrair 5 fatores
#
# NameError: name 'data' is not defined

# %% [markdown]
# # Cinco

# %%
chi_square_value, p_value = calculate_bartlett_sphericity(df)
print(f'Teste de esfericidade de Bartlett: chi2={chi_square_value}, p={p_value}')

kmo_all, kmo_model = calculate_kmo(df)
print(f'Medida KMO: {kmo_model}')

fa = FactorAnalyzer()
fa.fit(df)

ev, v = fa.get_eigenvalues()
print(f'Eigenvalues: {ev}')

plt.scatter(range(1, df.shape[1] + 1), ev)
plt.plot(range(1, df.shape[1] + 1), ev)
plt.title('Scree Plot')
plt.xlabel('Fatores')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

fa = FactorAnalyzer(n_factors=5, rotation='varimax')
fa.fit(df)

# Exibir as cargas fatoriais
factor_loadings = fa.loadings_
#print(f'Cargas fatoriais:\n{factor_loadings}')

# Exibir variância explicada por fator
variance = fa.get_factor_variance()
#print(f'Variância explicada por fator:\n{variance}')

# Passo 4: Interpretar os fatores
# Imprimir as cargas fatoriais de forma mais legível
cargas_fatoriais = pd.DataFrame(factor_loadings, index=df.columns, columns=['Fator 1', 'Fator 2', 'Fator 3', 'Fator 4', 'Fator 5'])
#print(f'Cargas fatoriais:\n{cargas_fatoriais}')

# Passo 5: Exibir variáveis carregadas em cada fator
limiar = 0.4  # Defina o limiar de carga fatorial

# Função para encontrar variáveis que carregam em cada fator
def variaveis_por_fator(loadings, threshold):
    fatores = {}
    for i in range(loadings.shape[1]):
        fator_name = f'Fator {i+1}'
        fatores[fator_name] = loadings.index[abs(loadings.iloc[:, i]) >= threshold].tolist()
    return fatores

# Obter variáveis carregadas em cada fator
variaveis_fatores = variaveis_por_fator(cargas_fatoriais, limiar)
for fator, variaveis in variaveis_fatores.items():
    print(f'{fator}',"=~", end="")
    for var in variaveis:
        print(f'  {var}', "+", end="")
    print("", end="\n")

# %%
model_desc = """
Fator1 =~ P24 + P32 + P34 + P36 + P41 + P25 + P39 + P40 + P35 + P29 + P43
Fator2 =~ P10 + P2 + P13 + P15 + P17 + P9 + P16 + P18 + P11 + P20 + P32  
Fator3 =~ P19 + P20 + P30 + P23 + P44 + P31 + P42 + P28 + P39
Fator4 =~ P15 + P17 + P6 + P19 + P12 + P22 + P44 + P26 + P37 + P38 + P14 + P43 
Fator5 =~ P4 + P7 + P21 + P8 + P11 + P12 + P42 + P27 + P29 + P43
"""

model = Model(model_desc)
model.fit(df)

stats = calc_stats(model=model)
print(stats)

# %% [markdown]
# # Dez

# %%
chi_square_value, p_value = calculate_bartlett_sphericity(df)
print(f'Teste de esfericidade de Bartlett: chi2={chi_square_value}, p={p_value}')
kmo_all, kmo_model = calculate_kmo(df)
print(f'Medida KMO: {kmo_model}')

fa = FactorAnalyzer()
fa.fit(df)
ev, v = fa.get_eigenvalues()

plt.scatter(range(1, df.shape[1] + 1), ev)
plt.plot(range(1, df.shape[1] + 1), ev)
plt.title('Scree Plot')
plt.xlabel('Fatores')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

fa = FactorAnalyzer(n_factors=10, rotation='varimax')
fa.fit(df)

factor_loadings = fa.loadings_
variance = fa.get_factor_variance()
cargas_fatoriais = pd.DataFrame(factor_loadings, index=df.columns, columns=['Fator 1', 'Fator 2', 'Fator 3', 'Fator 4', 'Fator 5', 'Fator 6', 'Fator 7', 'Fator 8', 'Fator 9', 'Fator 10'])

limiar = 0.4  

def variaveis_por_fator(loadings, threshold):
    fatores = {}
    for i in range(loadings.shape[1]):
        fator_name = f'Fator {i+1}'
        fatores[fator_name] = loadings.index[abs(loadings.iloc[:, i]) >= threshold].tolist()
    return fatores

variaveis_fatores = variaveis_por_fator(cargas_fatoriais, limiar)
for fator, variaveis in variaveis_fatores.items():
    print(f'{fator}',"=~ ", end="")
    for var in variaveis:
        print(f'{var}', "+ ", end="")
    print("", end="\n")

# %%
model_desc = """
Fator1 =~ P32 + P34 + P36 + P41 + P25 + P39 + P40 + P35 
Fator2 =~ P2 + P13 + P15 + P9 + P16 + P18 + P8 + P11 + P32 
Fator3 =~ P30 + P23 + P31 + P42 + P28 
Fator4 =~ P1 + P4 + P7 + P21 + P8 + P11 + P27 
Fator5 =~ P13 + P15 + P17 + P6 + P19 + P44 
Fator6 =~ P5 + P22 + P26 + P37 + P38
Fator7 =~ P44 + P40 + P14 + P43 
Fator8 =~ P3 + P12 + P20 + P22 + P24
Fator9 =~ P10 
Fator10 =~ P35 + P29 + P33
"""

model = Model(model_desc)
model.fit(df)

stats = calc_stats(model=model)
print(stats)

# %% [markdown]
# # 10 sem as colunas 35 e 28

# %%
df = df.drop(columns=['P28', 'P35'])

chi_square_value, p_value = calculate_bartlett_sphericity(df)
print(f'Teste de esfericidade de Bartlett: chi2={chi_square_value}, p={p_value}')
kmo_all, kmo_model = calculate_kmo(df)
print(f'Medida KMO: {kmo_model}')

fa = FactorAnalyzer()
fa.fit(df)
ev, v = fa.get_eigenvalues()

plt.scatter(range(1, df.shape[1] + 1), ev)
plt.plot(range(1, df.shape[1] + 1), ev)
plt.title('Scree Plot')
plt.xlabel('Fatores')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

fa = FactorAnalyzer(n_factors=10, rotation='varimax')
fa.fit(df)

factor_loadings = fa.loadings_
variance = fa.get_factor_variance()
cargas_fatoriais = pd.DataFrame(factor_loadings, index=df.columns, columns=['Fator 1', 'Fator 2', 'Fator 3', 'Fator 4', 'Fator 5', 'Fator 6', 'Fator 7', 'Fator 8', 'Fator 9', 'Fator 10'])

limiar = 0.4  

def variaveis_por_fator(loadings, threshold):
    fatores = {}
    for i in range(loadings.shape[1]):
        fator_name = f'Fator{i+1}'
        fatores[fator_name] = loadings.index[abs(loadings.iloc[:, i]) >= threshold].tolist()
    return fatores

variaveis_fatores = variaveis_por_fator(cargas_fatoriais, limiar)
for fator, variaveis in variaveis_fatores.items():
    print(f'{fator}',"=~ ", end="")
    for var in variaveis:
        print(f'{var}', "+ ", end="")
    print("", end="\n")

# %%
model_desc = """
Fator1 =~ P2 + P13 + P15 + P9 + P16 + P18 + P8 + P11 + P32 
Fator2 =~ P24 + P32 + P34 + P36 + P41 + P25 + P39 + P40
Fator3 =~ P1 + P4 + P7 + P21 + P8 + P11 + P27
Fator4 =~ P30 + P23 + P31 + P42
Fator5 =~ P13 + P15 + P17 + P6 + P19 + P44
Fator6 =~ P5 + P22 + P26 + P37 + P38
Fator7 =~ P44 + P40 + P14 + P43
Fator8 =~ P3 + P12 + P20 + P22 + P24
Fator9 =~ P10 + P15
Fator10 =~ P29 + P33
"""

model = Model(model_desc)
model.fit(df)

stats = calc_stats(model=model)
print(stats)

# %% [markdown]
# # 5 sem as colunas

# %%
chi_square_value, p_value = calculate_bartlett_sphericity(df)
print(f'Teste de esfericidade de Bartlett: chi2={chi_square_value}, p={p_value}')
kmo_all, kmo_model = calculate_kmo(df)
print(f'Medida KMO: {kmo_model}')

fa = FactorAnalyzer()
fa.fit(df)
ev, v = fa.get_eigenvalues()

plt.scatter(range(1, df.shape[1] + 1), ev)
plt.plot(range(1, df.shape[1] + 1), ev)
plt.title('Scree Plot')
plt.xlabel('Fatores')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

fa = FactorAnalyzer(n_factors=5, rotation='varimax')
fa.fit(df)

factor_loadings = fa.loadings_
variance = fa.get_factor_variance()
cargas_fatoriais = pd.DataFrame(factor_loadings, index=df.columns, columns=['Fator 1', 'Fator 2', 'Fator 3', 'Fator 4', 'Fator 5'])

limiar = 0.4  

def variaveis_por_fator(loadings, threshold):
    fatores = {}
    for i in range(loadings.shape[1]):
        fator_name = f'Fator{i+1}'
        fatores[fator_name] = loadings.index[abs(loadings.iloc[:, i]) >= threshold].tolist()
    return fatores

variaveis_fatores = variaveis_por_fator(cargas_fatoriais, limiar)
for fator, variaveis in variaveis_fatores.items():
    print(f'{fator}',"=~ ", end="")
    for var in variaveis:
        print(f'{var}', "+ ", end="")
    print("", end="\n")

# %%
model_desc = """
Fator1 =~ P10 + P2 + P13 + P15 + P17 + P9 + P16 + P18 + P11 + P20 + P32
Fator2 =~ P24 + P32 + P34 + P36 + P41 + P25 + P39 + P40 + P43 
Fator3 =~ P4 + P7 + P21 + P9 + P8 + P11 + P12 + P27 + P43 
Fator4 =~ P15 + P17 + P19 + P12 + P22 + P44 + P26 + P37 + P38 + P14 + P43 
Fator5 =~ P17 + P19 + P30 + P23 + P44 + P31 + P42
"""

model = Model(model_desc)
model.fit(df)

stats = calc_stats(model=model)
print(stats)

# %%
model_desc = """
Fator1 =~ P17 + P8 + P19 + P15 + P11
Fator2 =~ P34 + P35 + P41 + P17 + P15
Fator3 =~ P23 + P31 + P42 + P30 + P35
Fator4 =~ P27 + P11 + P21 + P8 + P1
Fator5 =~ P16 + P44 + P12 + P27 + P18
"""

model = Model(model_desc)
model.fit(df)

stats = calc_stats(model=model)
print(stats)

# %%
# Limpeza dos dados e normalização
df_cleaned = df.dropna().astype(float)
data_scaled = StandardScaler().fit_transform(df_cleaned)

# Testes de esfericidade de Bartlett e KMO
chi_square_value, p_value = calculate_bartlett_sphericity(data_scaled)
kmo_all, kmo_model = calculate_kmo(data_scaled)

print(f"Chi-Square Value: {chi_square_value}, p-value: {p_value}")
print(f"KMO Model: {kmo_model}")

# Determinar o número de fatores
fa = FactorAnalyzer(n_factors=22, rotation=None)
fa.fit(data_scaled)

# Extrair os eigenvalues
ev, v = fa.get_eigenvalues()

# Plotar os eigenvalues
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(range(1, df_cleaned.shape[1]+1), ev, marker='o', linestyle='--')
plt.title('Scree Plot')
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

# Escolher o número de fatores baseado no scree plot e eigenvalues
n_factors = sum(ev > 1)  # Critério de Kaiser

# Realizar a análise fatorial com o número escolhido de fatores
fa = FactorAnalyzer(n_factors=n_factors, rotation='varimax')
fa.fit(data_scaled)

# Mostrar as cargas fatoriais
loadings = fa.loadings_
#print(loadings)

cargas_fatoriais = pd.DataFrame(loadings, index=df.columns, columns=['Fator 1', 'Fator 2', 'Fator 3', 'Fator 4', 'Fator 5', 'Fator 6', 'Fator 7', 'Fator 8', 'Fator 9', 'Fator 10', 'Fator 11', 'Fator 12', 'Fator 13', 'Fator 14', 'Fator 15', 'Fator 16', 'Fator 17', 'Fator 18', 'Fator 19', 'Fator 20', 'Fator 21', 'Fator 22'])

limiar = 0.4  

def variaveis_por_fator(loadings, threshold):
    fatores = {}
    for i in range(loadings.shape[1]):
        fator_name = f'Fator{i+1}'
        fatores[fator_name] = loadings.index[abs(loadings.iloc[:, i]) >= threshold].tolist()
    return fatores

variaveis_fatores = variaveis_por_fator(cargas_fatoriais, limiar)
for fator, variaveis in variaveis_fatores.items():
    print(f'{fator}',"=~ ", end="")
    for var in variaveis:
        print(f'{var}', "+ ", end="")
    print("", end="\n")

# %% [markdown]
# # 12 Fatores

# %%
# Limpeza dos dados e normalização
df_cleaned = df.dropna().astype(float)
data_scaled = StandardScaler().fit_transform(df_cleaned)

# Testes de esfericidade de Bartlett e KMO
chi_square_value, p_value = calculate_bartlett_sphericity(data_scaled)
kmo_all, kmo_model = calculate_kmo(data_scaled)

print(f"Chi-Square Value: {chi_square_value}, p-value: {p_value}")
print(f"KMO Model: {kmo_model}")

# Determinar o número de fatores
fa = FactorAnalyzer(n_factors=22, rotation=None)
fa.fit(data_scaled)

# Extrair os eigenvalues
ev, v = fa.get_eigenvalues()

plt.figure(figsize=(10, 6))
plt.plot(range(1, df_cleaned.shape[1]+1), ev, marker='o', linestyle='--')
plt.title('Scree Plot')
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

# Escolher o número de fatores baseado no scree plot e eigenvalues
n_factors = sum(ev > 1)  # Critério de Kaiser

# Realizar a análise fatorial com o número escolhido de fatores
fa = FactorAnalyzer(n_factors=n_factors, rotation='varimax')
fa.fit(data_scaled)

# Mostrar as cargas fatoriais
loadings = fa.loadings_

# Exibir as variáveis que carregam fortemente em cada fator
threshold = 0.4  # Limite para considerar uma carga significativa
factors = {}

for i in range(n_factors):
    factors[f'Fator {i+1}'] = df_cleaned.columns[loadings[:, i] > threshold].tolist()

# Exibir as variáveis de cada fator
for factor, variables in factors.items():
    print(f"{factor}=~ {variables}")

# %%
model_desc = """
Fator1=~ P32 + P34 + P36 + P41 + P25 + P39 + P40 + P35
Fator2=~ P30 + P23 + P31 + P42 + P28
Fator3=~ P10 + P13 + P15 + P17 + P6 + P19 + P20
Fator4=~ P2 + P9 + P16 + P18 + P11 + P32
Fator5=~ P5 + P37 + P38 + P27
Fator6=~ P5 + P7 + P8 + P11 + P27
Fator7=~ P44 + P14 + P43
Fator8=~ P10 + P21 + P9 + P29
Fator9=~ P3 + P12 + P20 + P22
Fator10=~ P24 + P39
Fator11=~ P35 + P29 + P33
Fator12=~ P1 + P27
"""

model = Model(model_desc)
model.fit(df)

stats = calc_stats(model=model)
print(stats)
